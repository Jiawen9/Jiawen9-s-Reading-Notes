# %% [markdown]
# ## 集成学习：对比与调参
# 虽然现在深度学习大行其道，但以`XGBoost`、`LightGBM`、`CatBoost`为代表的`Boosting`算法仍有其广泛的用武之地。抛开深度学习适用的文本、图像、语音和视频等非结构化数据应用，对于训练样本较少的结构化数据领域，`Boosting`算法仍然是第一选择。

# %% [markdown]
# ### 1 三大Boosting算法对比
# `XGBoost`、`LightGBM`和`CatBoost`都是目前经典的`SOTA`(`state of the art`)Boosting算法，这三个模型都是以决策树为支撑的集成学习框架，其中XGBoost是对原始版本GBDT算法的改进，而`LightGBM`和`CatBoost`在`XGBoost`基础上做了进一步的优化，在精度和速度上各有所长。
#
# 三大Boosting算法主要有两个方面的区别：
#
# 第一，模型树的构造方式有所不同，`XGBoost`使用按层生长(`level-wise`)的决策树构建策略，LightGBM则使用按叶子生长(leaf-wise)的构建策略，而CatBoost使用对称树结构(oblivious-tree)，其决策树都是完全二叉树。
#
# 第二，对于类别特征的处理有较大区别，`XGBoost`本身不具备自动处理类别特征的能力，对于数据中的类别特征，需要我们手动处理变换成数值后才能输入到模型中；`LightGBM`中则需要指定类别特征名称，算法会自动对齐进行处理；`CatBoost`以处理类别特征而闻名，通过目标变量统计等特征编码方式也能实现高效处理类别特征。

# %% [markdown]
# #### 1.1 数据预处理
# 下面以 `Kaggle` 2015年的`flights`数据集为例，分别用`XGBoost`、`LightGBM`和`CatBoost`模型进行实验：
#
# 该数据集共有500多万条航班记录数据，特征有31个。我们采取抽样的方式从原始数据集中抽取1%的数据，并筛选11个特征用作演示，经过预处理后重新构建训练集，目标是构建对航班是否延误的二分类模型。

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
flights = pd.read_csv('flights.csv')
flights = flights.sample(frac=0.01, random_state=10) # 数据集抽样1%
flights
# Out:
# d:\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3106: DtypeWarning: Columns (7,8) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#          YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 411984   2015      1   28            3      WN            103      N7728D
# 3591965  2015      8   11            2      B6            153      N592JB
# 526451   2015      2    4            3      DL           1187      N921DN
# 1336011  2015      3   27            5      WN            171      N407WN
# 3424502  2015      8    1            6      WN           4330      N7751A
# ...       ...    ...  ...          ...     ...            ...         ...
# 4837220  2015     10   29            4      EV           4727      N14907
# 3829515  2015      8   26            3      B6            886      N568JB
# 49110    2015      1    4            7      US           2024      N194UW
# 4936756  2015     11    5            4      WN           1700      N905WN
# 4472302  2015     10    6            2      OO           5182      N962SW
#
#         ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  ...  \
# 411984             DCA                 MKE                  705  ...
# 3591965            JFK                 PBI                 1859  ...
# 526451             MSP                 DCA                 1735  ...
# 1336011            DEN                 RDU                 1815  ...
# 3424502            ATL                 RIC                 2125  ...
# ...                ...                 ...                  ...  ...
# 4837220          11775               13930                 1444  ...
# 3829515            RDU                 JFK                 1010  ...
# 49110              SEA                 PHX                  825  ...
# 4936756            BUF                 MDW                  545  ...
# 4472302          13433               11292                 1340  ...
#
#          ARRIVAL_TIME  ARRIVAL_DELAY  DIVERTED  CANCELLED  \
# 411984          811.0            1.0         0          0
# 3591965         345.0          337.0         0          0
# 526451         2043.0          -19.0         0          0
# 1336011        2313.0           -7.0         0          0
# 3424502        2318.0           13.0         0          0
# ...               ...            ...       ...        ...
# 4837220        1625.0            0.0         0          0
# 3829515        1127.0          -21.0         0          0
# 49110          1147.0          -23.0         0          0
# 4936756         610.0          -30.0         0          0
# 4472302        1442.0            5.0         0          0
#
#          CANCELLATION_REASON  AIR_SYSTEM_DELAY  SECURITY_DELAY  AIRLINE_DELAY  \
# 411984                   NaN               NaN             NaN            NaN
# 3591965                  NaN               0.0             0.0           82.0
# 526451                   NaN               NaN             NaN            NaN
# 1336011                  NaN               NaN             NaN            NaN
# 3424502                  NaN               NaN             NaN            NaN
# ...                      ...               ...             ...            ...
# 4837220                  NaN               NaN             NaN            NaN
# 3829515                  NaN               NaN             NaN            NaN
# 49110                    NaN               NaN             NaN            NaN
# 4936756                  NaN               NaN             NaN            NaN
# 4472302                  NaN               NaN             NaN            NaN
#
#          LATE_AIRCRAFT_DELAY  WEATHER_DELAY
# 411984                   NaN            NaN
# 3591965                255.0            0.0
# 526451                   NaN            NaN
# 1336011                  NaN            NaN
# 3424502                  NaN            NaN
# ...                      ...            ...
# 4837220                  NaN            NaN
# 3829515                  NaN            NaN
# 49110                    NaN            NaN
# 4936756                  NaN            NaN
# 4472302                  NaN            NaN
#
# [58191 rows x 31 columns]

# %%
flights = flights[["MONTH","DAY","DAY_OF_WEEK","AIRLINE","FLIGHT_NUMBER","DESTINATION_AIRPORT",
                 "ORIGIN_AIRPORT","AIR_TIME", "DEPARTURE_TIME","DISTANCE","ARRIVAL_DELAY"]] # 选11个特征
flights= flights.reset_index(drop=True)
flights
# Out:
#        MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER DESTINATION_AIRPORT  \
# 0          1   28            3      WN            103                 MKE
# 1          8   11            2      B6            153                 PBI
# 2          2    4            3      DL           1187                 DCA
# 3          3   27            5      WN            171                 RDU
# 4          8    1            6      WN           4330                 RIC
# ...      ...  ...          ...     ...            ...                 ...
# 58186     10   29            4      EV           4727               13930
# 58187      8   26            3      B6            886                 JFK
# 58188      1    4            7      US           2024                 PHX
# 58189     11    5            4      WN           1700                 MDW
# 58190     10    6            2      OO           5182               11292
#
#       ORIGIN_AIRPORT  AIR_TIME  DEPARTURE_TIME  DISTANCE  ARRIVAL_DELAY
# 0                DCA     102.0           713.0       634            1.0
# 1                JFK     134.0           111.0      1028          337.0
# 2                MSP     111.0          1734.0       931          -19.0
# 3                DEN     173.0          1807.0      1436           -7.0
# 4                ATL      63.0          2151.0       481           13.0
# ...              ...       ...             ...       ...            ...
# 58186          11775      81.0          1438.0       462            0.0
# 58187            RDU      61.0          1005.0       427          -21.0
# 58188            SEA     131.0           825.0      1107          -23.0
# 58189            BUF      75.0           541.0       468          -30.0
# 58190          13433      91.0          1355.0       604            5.0
#
# [58191 rows x 11 columns]

# %%
flights["ARRIVAL_DELAY"] = (flights["ARRIVAL_DELAY"]>10)*1 # 延误超过10分钟看作是延误，bool类型转换为int类型
flights["ARRIVAL_DELAY"].unique()
# Out:
# array([0, 1], dtype=int32)

# %%
cols = ["AIRLINE","FLIGHT_NUMBER","DESTINATION_AIRPORT","ORIGIN_AIRPORT"] # 类别特征
for col in cols:
    print(len(flights[col].unique()))
# Out:
# 14
# 6163
# 633
# 644

# %%
for item in cols:
    flights[item] = flights[item].astype("category").cat.codes

X_train, X_test, y_train, y_test = train_test_split(flights.drop(["ARRIVAL_DELAY"], axis=1), flights["ARRIVAL_DELAY"], random_state=10, test_size=0.3) # 划分数据集

# %% [markdown]
# #### 1.2 XGBoost在flights数据集上的测试

# %%
from sklearn.metrics import roc_auc_score
import xgboost as xgb
import time

# 设置模型参数
params = {
    'booster': 'gbtree', # 基于树
    'objective': 'binary:logistic',   
    'gamma': 0.1, # 剪枝中用到的最小损失下降值
    'max_depth': 8,
    'lambda': 2,
    'subsample': 0.7, # 表示用于训练的样本比例
    'colsample_bytree': 0.7, # 表示用于训练的特征比例
    'min_child_weight': 3, # 一个叶子节点的最小权重
    'eta': 0.001,# 学习速率
    'seed': 1000,
    'nthread': 4, # 线程数量，用于并行计算
}

# 训练
t0 = time.time()
num_rounds = 500 # 表示训练轮数，即树的个数
dtrain = xgb.DMatrix(X_train, y_train)
model_xgb = xgb.train(params, dtrain, num_rounds)
print('training spend {} seconds'.format(time.time()-t0))

# 测试
t1 = time.time()
dtest = xgb.DMatrix(X_test)
y_pred = model_xgb.predict(dtest)
print('testing spend {} seconds'.format(time.time()-t1))
y_pred_train = model_xgb.predict(dtrain)
print(f"训练集auc：{roc_auc_score(y_train, y_pred_train)}")
print(f"测试集auc：{roc_auc_score(y_test, y_pred)}")
# Out:
# training spend 6.46193265914917 seconds
# testing spend 0.057062625885009766 seconds
# 训练集auc：0.752049936354563
# 测试集auc：0.6965194979943091

# %% [markdown]
# #### 1.3 LightGBM在flights数据集上的测试

# %%
import lightgbm as lgb
d_train = lgb.Dataset(X_train, label=y_train)

# 设置模型参数
params = {
    "max_depth": 5, 
    "learning_rate" : 0.05, 
    "num_leaves": 500,  
    "n_estimators": 300
}

cate_features_name = ["MONTH","DAY","DAY_OF_WEEK","AIRLINE","DESTINATION_AIRPORT", "ORIGIN_AIRPORT"] # 类别特征

t0 = time.time()
model_lgb = lgb.train(params, d_train, categorical_feature = cate_features_name)
print('training spend {} seconds'.format(time.time()-t0))
t1 = time.time()

y_pred = model_lgb.predict(X_test)
print('testing spend {} seconds'.format(time.time()-t1))
y_pred_train = model_lgb.predict(X_train)
print(f"训练集auc：{roc_auc_score(y_train, y_pred_train)}")
print(f"测试集auc：{roc_auc_score(y_test, y_pred)}")
# Out:
# d:\anaconda3\lib\site-packages\lightgbm\engine.py:177: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# d:\anaconda3\lib\site-packages\lightgbm\basic.py:2068: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is ['AIRLINE', 'DAY', 'DAY_OF_WEEK', 'DESTINATION_AIRPORT', 'MONTH', 'ORIGIN_AIRPORT']
#   _log_warning('categorical_feature in Dataset is overridden.\n'
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000872 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1862
# [LightGBM] [Info] Number of data points in the train set: 40733, number of used features: 10
# [LightGBM] [Info] Start training from score 0.211327
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# training spend 0.43550848960876465 seconds
# testing spend 0.0230252742767334 seconds
# 训练集auc：0.8867447004324996
# 测试集auc：0.7033506245405025

# %% [markdown]
# #### 1.2 CatBoost在flights数据集上的测试

# %%
import catboost as cb
cat_features_index = [0,1,2,3,4,5,6]

t0 = time.time()
model_cb = cb.CatBoostClassifier(eval_metric="AUC", one_hot_max_size=50, depth=6, iterations=300, l2_leaf_reg=1, learning_rate=0.1)
model_cb.fit(X_train,y_train, cat_features= cat_features_index)
print('training spend {} seconds'.format(time.time()-t0))

t1 = time.time()
y_pred = model_cb.predict(X_test)
print('testing spend {} seconds'.format(time.time()-t1))
y_pred_train = model_cb.predict(X_train)
print(f"训练集auc：{roc_auc_score(y_train, y_pred_train)}")
print(f"测试集auc：{roc_auc_score(y_test, y_pred)}")
# Out:
# 0:	total: 198ms	remaining: 59.1s
# 1:	total: 254ms	remaining: 37.8s
# 2:	total: 303ms	remaining: 30s
# 3:	total: 353ms	remaining: 26.1s
# 4:	total: 403ms	remaining: 23.8s
# 5:	total: 454ms	remaining: 22.2s
# 6:	total: 505ms	remaining: 21.1s
# 7:	total: 551ms	remaining: 20.1s
# 8:	total: 602ms	remaining: 19.5s
# 9:	total: 657ms	remaining: 19s
# 10:	total: 719ms	remaining: 18.9s
# 11:	total: 772ms	remaining: 18.5s
# 12:	total: 821ms	remaining: 18.1s
# 13:	total: 875ms	remaining: 17.9s
# 14:	total: 925ms	remaining: 17.6s
# 15:	total: 979ms	remaining: 17.4s
# 16:	total: 1.03s	remaining: 17.1s
# 17:	total: 1.08s	remaining: 16.9s
# 18:	total: 1.11s	remaining: 16.5s
# 19:	total: 1.16s	remaining: 16.2s
# 20:	total: 1.21s	remaining: 16.1s
# 21:	total: 1.26s	remaining: 16s
# 22:	total: 1.32s	remaining: 15.9s
# 23:	total: 1.38s	remaining: 15.9s
# 24:	total: 1.44s	remaining: 15.8s
# 25:	total: 1.49s	remaining: 15.7s
# 26:	total: 1.54s	remaining: 15.6s
# 27:	total: 1.6s	remaining: 15.5s
# 28:	total: 1.65s	remaining: 15.4s
# 29:	total: 1.7s	remaining: 15.3s
# 30:	total: 1.75s	remaining: 15.2s
# 31:	total: 1.81s	remaining: 15.2s
# 32:	total: 1.86s	remaining: 15s
# 33:	total: 1.91s	remaining: 14.9s
# 34:	total: 1.96s	remaining: 14.8s
# 35:	total: 2.01s	remaining: 14.7s
# 36:	total: 2.06s	remaining: 14.7s
# 37:	total: 2.11s	remaining: 14.6s
# 38:	total: 2.19s	remaining: 14.7s
# 39:	total: 2.25s	remaining: 14.6s
# 40:	total: 2.3s	remaining: 14.6s
# 41:	total: 2.36s	remaining: 14.5s
# 42:	total: 2.42s	remaining: 14.5s
# 43:	total: 2.48s	remaining: 14.4s
# 44:	total: 2.53s	remaining: 14.4s
# 45:	total: 2.59s	remaining: 14.3s
# 46:	total: 2.64s	remaining: 14.2s
# 47:	total: 2.7s	remaining: 14.2s
# 48:	total: 2.77s	remaining: 14.2s
# 49:	total: 2.83s	remaining: 14.2s
# 50:	total: 2.89s	remaining: 14.1s
# 51:	total: 2.94s	remaining: 14s
# 52:	total: 3s	remaining: 14s
# 53:	total: 3.05s	remaining: 13.9s
# 54:	total: 3.1s	remaining: 13.8s
# 55:	total: 3.16s	remaining: 13.8s
# 56:	total: 3.22s	remaining: 13.7s
# 57:	total: 3.28s	remaining: 13.7s
# 58:	total: 3.34s	remaining: 13.6s
# 59:	total: 3.39s	remaining: 13.6s
# 60:	total: 3.45s	remaining: 13.5s
# 61:	total: 3.5s	remaining: 13.4s
# 62:	total: 3.56s	remaining: 13.4s
# 63:	total: 3.62s	remaining: 13.3s
# 64:	total: 3.68s	remaining: 13.3s
# 65:	total: 3.75s	remaining: 13.3s
# 66:	total: 3.8s	remaining: 13.2s
# 67:	total: 3.86s	remaining: 13.2s
# 68:	total: 3.92s	remaining: 13.1s
# 69:	total: 3.98s	remaining: 13.1s
# 70:	total: 4.04s	remaining: 13s
# 71:	total: 4.09s	remaining: 13s
# 72:	total: 4.14s	remaining: 12.9s
# 73:	total: 4.2s	remaining: 12.8s
# 74:	total: 4.26s	remaining: 12.8s
# 75:	total: 4.32s	remaining: 12.7s
# 76:	total: 4.37s	remaining: 12.7s
# 77:	total: 4.42s	remaining: 12.6s
# 78:	total: 4.48s	remaining: 12.5s
# 79:	total: 4.54s	remaining: 12.5s
# 80:	total: 4.6s	remaining: 12.4s
# 81:	total: 4.66s	remaining: 12.4s
# 82:	total: 4.71s	remaining: 12.3s
# 83:	total: 4.76s	remaining: 12.3s
# 84:	total: 4.82s	remaining: 12.2s
# 85:	total: 4.88s	remaining: 12.1s
# 86:	total: 4.93s	remaining: 12.1s
# 87:	total: 4.99s	remaining: 12s
# 88:	total: 5.06s	remaining: 12s
# 89:	total: 5.12s	remaining: 11.9s
# 90:	total: 5.17s	remaining: 11.9s
# 91:	total: 5.23s	remaining: 11.8s
# 92:	total: 5.29s	remaining: 11.8s
# 93:	total: 5.35s	remaining: 11.7s
# 94:	total: 5.41s	remaining: 11.7s
# 95:	total: 5.47s	remaining: 11.6s
# 96:	total: 5.53s	remaining: 11.6s
# 97:	total: 5.59s	remaining: 11.5s
# 98:	total: 5.66s	remaining: 11.5s
# 99:	total: 5.72s	remaining: 11.4s
# 100:	total: 5.78s	remaining: 11.4s
# 101:	total: 5.84s	remaining: 11.3s
# 102:	total: 5.9s	remaining: 11.3s
# 103:	total: 5.97s	remaining: 11.3s
# 104:	total: 6.04s	remaining: 11.2s
# 105:	total: 6.1s	remaining: 11.2s
# 106:	total: 6.17s	remaining: 11.1s
# 107:	total: 6.24s	remaining: 11.1s
# 108:	total: 6.3s	remaining: 11s
# 109:	total: 6.36s	remaining: 11s
# 110:	total: 6.43s	remaining: 11s
# 111:	total: 6.5s	remaining: 10.9s
# 112:	total: 6.56s	remaining: 10.9s
# 113:	total: 6.63s	remaining: 10.8s
# 114:	total: 6.7s	remaining: 10.8s
# 115:	total: 6.76s	remaining: 10.7s
# 116:	total: 6.83s	remaining: 10.7s
# 117:	total: 6.9s	remaining: 10.6s
# 118:	total: 6.97s	remaining: 10.6s
# 119:	total: 7.05s	remaining: 10.6s
# 120:	total: 7.11s	remaining: 10.5s
# 121:	total: 7.18s	remaining: 10.5s
# 122:	total: 7.25s	remaining: 10.4s
# 123:	total: 7.31s	remaining: 10.4s
# 124:	total: 7.38s	remaining: 10.3s
# 125:	total: 7.45s	remaining: 10.3s
# 126:	total: 7.52s	remaining: 10.2s
# 127:	total: 7.59s	remaining: 10.2s
# 128:	total: 7.66s	remaining: 10.1s
# 129:	total: 7.72s	remaining: 10.1s
# 130:	total: 7.8s	remaining: 10.1s
# 131:	total: 7.87s	remaining: 10s
# 132:	total: 7.94s	remaining: 9.96s
# 133:	total: 8.01s	remaining: 9.92s
# 134:	total: 8.07s	remaining: 9.86s
# 135:	total: 8.14s	remaining: 9.81s
# 136:	total: 8.2s	remaining: 9.76s
# 137:	total: 8.27s	remaining: 9.71s
# 138:	total: 8.34s	remaining: 9.66s
# 139:	total: 8.4s	remaining: 9.61s
# 140:	total: 8.47s	remaining: 9.55s
# 141:	total: 8.55s	remaining: 9.51s
# 142:	total: 8.61s	remaining: 9.46s
# 143:	total: 8.68s	remaining: 9.4s
# 144:	total: 8.74s	remaining: 9.35s
# 145:	total: 8.81s	remaining: 9.3s
# 146:	total: 8.88s	remaining: 9.25s
# 147:	total: 8.95s	remaining: 9.2s
# 148:	total: 9.02s	remaining: 9.14s
# 149:	total: 9.09s	remaining: 9.09s
# 150:	total: 9.16s	remaining: 9.04s
# 151:	total: 9.23s	remaining: 8.99s
# 152:	total: 9.3s	remaining: 8.94s
# 153:	total: 9.37s	remaining: 8.88s
# 154:	total: 9.44s	remaining: 8.83s
# 155:	total: 9.51s	remaining: 8.78s
# 156:	total: 9.58s	remaining: 8.72s
# 157:	total: 9.64s	remaining: 8.67s
# 158:	total: 9.71s	remaining: 8.61s
# 159:	total: 9.78s	remaining: 8.56s
# 160:	total: 9.85s	remaining: 8.5s
# 161:	total: 9.92s	remaining: 8.45s
# 162:	total: 9.99s	remaining: 8.4s
# 163:	total: 10.1s	remaining: 8.35s
# 164:	total: 10.1s	remaining: 8.29s
# 165:	total: 10.2s	remaining: 8.24s
# 166:	total: 10.3s	remaining: 8.18s
# 167:	total: 10.3s	remaining: 8.13s
# 168:	total: 10.4s	remaining: 8.08s
# 169:	total: 10.5s	remaining: 8.02s
# 170:	total: 10.6s	remaining: 7.97s
# 171:	total: 10.6s	remaining: 7.92s
# 172:	total: 10.7s	remaining: 7.86s
# 173:	total: 10.8s	remaining: 7.8s
# 174:	total: 10.8s	remaining: 7.75s
# 175:	total: 10.9s	remaining: 7.69s
# 176:	total: 11s	remaining: 7.63s
# 177:	total: 11.1s	remaining: 7.58s
# 178:	total: 11.1s	remaining: 7.53s
# 179:	total: 11.2s	remaining: 7.47s
# 180:	total: 11.3s	remaining: 7.42s
# 181:	total: 11.4s	remaining: 7.36s
# 182:	total: 11.4s	remaining: 7.31s
# 183:	total: 11.5s	remaining: 7.25s
# 184:	total: 11.6s	remaining: 7.19s
# 185:	total: 11.6s	remaining: 7.14s
# 186:	total: 11.7s	remaining: 7.08s
# 187:	total: 11.8s	remaining: 7.03s
# 188:	total: 11.9s	remaining: 6.97s
# 189:	total: 11.9s	remaining: 6.91s
# 190:	total: 12s	remaining: 6.86s
# 191:	total: 12.1s	remaining: 6.8s
# 192:	total: 12.2s	remaining: 6.74s
# 193:	total: 12.2s	remaining: 6.68s
# 194:	total: 12.3s	remaining: 6.63s
# 195:	total: 12.4s	remaining: 6.57s
# 196:	total: 12.5s	remaining: 6.51s
# 197:	total: 12.5s	remaining: 6.46s
# 198:	total: 12.6s	remaining: 6.4s
# 199:	total: 12.7s	remaining: 6.34s
# 200:	total: 12.8s	remaining: 6.28s
# 201:	total: 12.8s	remaining: 6.22s
# 202:	total: 12.9s	remaining: 6.17s
# 203:	total: 13s	remaining: 6.1s
# 204:	total: 13s	remaining: 6.04s
# 205:	total: 13.1s	remaining: 5.99s
# 206:	total: 13.2s	remaining: 5.93s
# 207:	total: 13.3s	remaining: 5.87s
# 208:	total: 13.3s	remaining: 5.81s
# 209:	total: 13.4s	remaining: 5.75s
# 210:	total: 13.5s	remaining: 5.69s
# 211:	total: 13.6s	remaining: 5.63s
# 212:	total: 13.6s	remaining: 5.58s
# 213:	total: 13.7s	remaining: 5.52s
# 214:	total: 13.8s	remaining: 5.46s
# 215:	total: 13.9s	remaining: 5.4s
# 216:	total: 14s	remaining: 5.34s
# 217:	total: 14.1s	remaining: 5.29s
# 218:	total: 14.1s	remaining: 5.22s
# 219:	total: 14.2s	remaining: 5.17s
# 220:	total: 14.3s	remaining: 5.1s
# 221:	total: 14.4s	remaining: 5.04s
# 222:	total: 14.4s	remaining: 4.99s
# 223:	total: 14.5s	remaining: 4.93s
# 224:	total: 14.6s	remaining: 4.87s
# 225:	total: 14.7s	remaining: 4.81s
# 226:	total: 14.8s	remaining: 4.75s
# 227:	total: 14.8s	remaining: 4.69s
# 228:	total: 14.9s	remaining: 4.63s
# 229:	total: 15s	remaining: 4.56s
# 230:	total: 15.1s	remaining: 4.5s
# 231:	total: 15.1s	remaining: 4.44s
# 232:	total: 15.2s	remaining: 4.38s
# 233:	total: 15.3s	remaining: 4.31s
# 234:	total: 15.4s	remaining: 4.25s
# 235:	total: 15.5s	remaining: 4.19s
# 236:	total: 15.5s	remaining: 4.13s
# 237:	total: 15.6s	remaining: 4.06s
# 238:	total: 15.7s	remaining: 4s
# 239:	total: 15.7s	remaining: 3.94s
# 240:	total: 15.8s	remaining: 3.87s
# 241:	total: 15.9s	remaining: 3.81s
# 242:	total: 16s	remaining: 3.75s
# 243:	total: 16s	remaining: 3.68s
# 244:	total: 16.1s	remaining: 3.62s
# 245:	total: 16.2s	remaining: 3.56s
# 246:	total: 16.3s	remaining: 3.49s
# 247:	total: 16.4s	remaining: 3.43s
# 248:	total: 16.4s	remaining: 3.36s
# 249:	total: 16.5s	remaining: 3.3s
# 250:	total: 16.6s	remaining: 3.24s
# 251:	total: 16.7s	remaining: 3.17s
# 252:	total: 16.7s	remaining: 3.11s
# 253:	total: 16.8s	remaining: 3.04s
# 254:	total: 16.9s	remaining: 2.98s
# 255:	total: 17s	remaining: 2.91s
# 256:	total: 17s	remaining: 2.85s
# 257:	total: 17.1s	remaining: 2.78s
# 258:	total: 17.2s	remaining: 2.72s
# 259:	total: 17.2s	remaining: 2.65s
# 260:	total: 17.3s	remaining: 2.59s
# 261:	total: 17.4s	remaining: 2.52s
# 262:	total: 17.5s	remaining: 2.46s
# 263:	total: 17.6s	remaining: 2.4s
# 264:	total: 17.6s	remaining: 2.33s
# 265:	total: 17.7s	remaining: 2.27s
# 266:	total: 17.8s	remaining: 2.2s
# 267:	total: 17.9s	remaining: 2.13s
# 268:	total: 18s	remaining: 2.07s
# 269:	total: 18s	remaining: 2s
# 270:	total: 18.1s	remaining: 1.94s
# 271:	total: 18.2s	remaining: 1.87s
# 272:	total: 18.3s	remaining: 1.81s
# 273:	total: 18.3s	remaining: 1.74s
# 274:	total: 18.4s	remaining: 1.68s
# 275:	total: 18.5s	remaining: 1.61s
# 276:	total: 18.6s	remaining: 1.54s
# 277:	total: 18.7s	remaining: 1.48s
# 278:	total: 18.7s	remaining: 1.41s
# 279:	total: 18.8s	remaining: 1.34s
# 280:	total: 18.9s	remaining: 1.28s
# 281:	total: 19s	remaining: 1.21s
# 282:	total: 19.1s	remaining: 1.14s
# 283:	total: 19.1s	remaining: 1.08s
# 284:	total: 19.2s	remaining: 1.01s
# 285:	total: 19.3s	remaining: 944ms
# 286:	total: 19.4s	remaining: 877ms
# 287:	total: 19.4s	remaining: 810ms
# 288:	total: 19.5s	remaining: 743ms
# 289:	total: 19.6s	remaining: 676ms
# 290:	total: 19.7s	remaining: 609ms
# 291:	total: 19.8s	remaining: 542ms
# 292:	total: 19.9s	remaining: 474ms
# 293:	total: 19.9s	remaining: 407ms
# 294:	total: 20s	remaining: 339ms
# 295:	total: 20.1s	remaining: 271ms
# 296:	total: 20.2s	remaining: 204ms
# 297:	total: 20.2s	remaining: 136ms
# 298:	total: 20.3s	remaining: 67.9ms
# 299:	total: 20.4s	remaining: 0us
# training spend 20.633496284484863 seconds
# testing spend 0.03611636161804199 seconds
# 训练集auc：0.5670692017560355
# 测试集auc：0.5473357824098838

# %% [markdown]
# 由上面的实验结果可以看出在没有做进一步数据特征工程和超参数调优的情况下，在该数据集上，`LightGBM`无论是精度上还是速度上都要优于`XGBoost`和`CatBoost`，`CatBoost`的表现最差。

# %% [markdown]
# ### 2 常用超参数调优方法
# 我们将不经过模型训练得到的参数叫做`超参数`(`hyperparameter`)，机器学习中常用的调参方法包括`网格搜索法`(`grid search`)、`随机搜索法`(`random search`)和`贝叶斯优化`(`bayesian optimization`)。

# %% [markdown]
# #### 2.1 网格搜索法
# 网格搜索法是一种常用的超参数调优方法，常用于优化三个或者更少数量的超参数，本质上是一种穷举法。对于每个超参数，使用者选择一个较小的有限集去搜索，然后将这些超参数经过笛卡尔乘积得到若干组超参数。网格搜索使用每组超参数训练模型，挑选验证集误差最小的超参数作为最优化超参数。
#
# `sklearn`通过`model_selection`模块下的`GridSearchCV`来实现网格搜索调参，并且这个调参过程是加了交叉验证的。下面展示XGBoost的网格搜索示例：

# %%
# 基于XGBoost的GridSearch搜索范例
from sklearn.model_selection import GridSearchCV

model = xgb.XGBClassifier()

# 待搜索的参数列表实例
params_lst = {
    'max_depth': [3,5,7], 
    'min_child_weight': [1,3,6], 
    'n_estimators': [100,200,300],
    'learning_rate': [0.01, 0.05, 0.1]
}

# verbose：表示日志输出的详细程度
# n_jobs：表示并行计算的数量，即同时运行的任务数，-1 表示使用所有可用的 CPU 进行并行计算
t0 = time.time()
grid_search = GridSearchCV(model, param_grid=params_lst, cv=3, verbose=10, n_jobs=-1)
grid_search.fit(X_train, y_train)
print('gridsearch for xgb spend', time.time()-t0, 'seconds.')
print(grid_search.best_params_)
# Out:
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# gridsearch for xgb spend 67.24716424942017 seconds.
# {'learning_rate': 0.1, 'max_depth': 5, 'min_child_weight': 6, 'n_estimators': 300}

# %% [markdown]
# #### 2.2 随机搜索
# 随即搜索是在指定超参数范围内或者分布上随即搜寻最优超参数。相较于网格搜索方法，给定超参数分布，并不是所有超参数都要尝试，而是会从给定分布中抽样固定数量的参数，实际仅对这些抽样到的超参数进行实验。
#
# `sklearn`通过model_selection模块下的`RandomizedSearchCV`方法进行随即搜索。

# %%
# 基于XGBoost的RandomizedSearch搜索范例
from sklearn.model_selection import RandomizedSearchCV # 通过 n_iter 进行手动设置或是自动根据参数空间大小确定采样次数

model = xgb.XGBClassifier()

# 待搜索的参数列表实例
params_lst = {
    'max_depth': [3,5,7], 
    'min_child_weight': [1,3,6], 
    'n_estimators': [100,200,300],
    'learning_rate': [0.01, 0.05, 0.1]
}

t0 = time.time()
random_search = RandomizedSearchCV(model, params_lst, random_state=0)
random_search.fit(X_train, y_train)
print(random_search.best_params_)
print('randomsearch for xgb spend', time.time()-t0, 'seconds.')
# Out:
# {'n_estimators': 300, 'min_child_weight': 6, 'max_depth': 5, 'learning_rate': 0.1}
# randomsearch for xgb spend 60.41917014122009 seconds.

# %% [markdown]
# #### 2.3 贝叶斯调参
# 贝叶斯调参（Bayesian Optimization）是一种基于贝叶斯定理的超参数优化方法，主要用于优化黑盒函数。相对于传统的网格搜索或随机搜索，贝叶斯调参基于样本观测的不确定性建立模型，通过贝叶斯公式计算后验分布，从中选择期望相对较高的超参数进行优化。
#
# 贝叶斯调参的关键思想是利用样本观测不断地更新模型的先验（前提假设），并在已知前提基础上预测下一个实验的结果。通过预测的结果，更新模型的后验分布，即已知样本后，超参数分布的概率密度函数。在超参数概率密度函数的统计学指标（比如期望和方差）的基础上，生成下一组超参数值，直到达到最优结果为止。在整个过程中，下一组待测试的超参数都是在当前已有数据的基础上，反向计算已有样本的超参数概率分布，并根据超参数的期望值（或模式）来进行搜索，在一定程度上使搜索更加“聪明”和高效。

# %%
# pip install bayesian-optimization

# 定义相关参数
num_rounds = 3000

params = {
    'eta': 0.1,
    'silent': 1,
    'eval_metric': 'auc',
    'verbose_eval': True,
    'seed': 2023
}

# 定义目标优化函数
def xgb_evaluate(min_child_weight, colsample_bytree, max_depth, subsample, gamma,alpha):

    params['min_child_weight'] = int(min_child_weight)
    params['cosample_bytree'] = max(min(colsample_bytree, 1), 0)
    params['max_depth'] = int(max_depth)
    params['subsample'] = max(min(subsample, 1), 0)
    params['gamma'] = max(gamma, 0)
    params['alpha'] = max(alpha, 0)

    cv_result = xgb.cv(params, dtrain, num_boost_round=num_rounds, nfold=5, seed=2023, callbacks=[xgb.callback.EarlyStopping(rounds=50)])

    return cv_result['test-auc-mean'].values[-1]

# %%
# pip install bayesian-optimization
from bayes_opt import BayesianOptimization
#-*-coding:utf-8-*-

num_iter = 25
init_points = 5

t0 = time.time()
xgbBO = BayesianOptimization(xgb_evaluate, {
    'min_child_weight': (1, 20),
    'colsample_bytree': (0.1, 1),
    'max_depth': (5, 15),
    'subsample': (0.5, 1),
    'gamma': (0, 10),
    'alpha': (0, 10),
})
xgbBO.maximize(init_points=init_points, n_iter=num_iter)
print('bayesianSearch for xgb spend', time.time()-t0, 'seconds.')
# Out:
# |   iter    |  target   |   alpha   | colsam... |   gamma   | max_depth | min_ch... | subsample |
# -------------------------------------------------------------------------------------------------
# [17:44:15] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:44:15] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:44:15] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:44:15] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:44:15] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# | 1         | 0.7193    | 7.155     | 0.5762    | 0.9578    | 9.488     | 13.18     | 0.9343    |
# [17:45:17] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:45:17] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:45:17] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:45:17] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:45:17] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# | 2         | 0.7072    | 9.721     | 0.1613    | 2.222     | 10.18     | 4.347     | 0.951     |
# [17:47:22] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:47:22] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:47:22] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:47:22] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:47:23] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# | 3         | 0.691     | 7.762     | 0.929     | 4.644     | 14.7      | 19.21     | 0.5844    |
# [17:48:58] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:48:58] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:48:58] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:48:58] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:48:58] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# | 4         | 0.67      | 3.58      | 0.3663    | 9.356     | 6.879     | 10.64     | 0.8412    |
# [17:49:16] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:49:16] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:49:16] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:49:16] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:49:16] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# | 5         | 0.6906    | 4.188     | 0.2002    | 6.312     | 10.76     | 13.3      | 0.7996    |
# [17:50:18] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:50:18] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:50:18] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:50:18] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:50:18] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# | 6         | 0.7188    | 8.394     | 0.4757    | 0.4957    | 9.759     | 10.4      | 0.9573    |
# [17:50:39] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:50:39] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:50:39] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:50:39] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:50:39] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# | 7         | 0.7133    | 10.0      | 0.1       | 0.0       | 5.0       | 15.37     | 0.5       |
# [17:50:58] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:50:58] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:50:58] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:50:58] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:50:58] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# | 8         | 0.6738    | 0.0       | 1.0       | 0.0       | 15.0      | 1.0       | 0.5       |
# [17:51:22] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:51:22] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:51:22] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:51:22] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:51:22] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# | 9         | 0.7194    | 0.0       | 1.0       | 0.0       | 5.0       | 20.0      | 1.0       |
# [17:51:37] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:51:37] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:51:37] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:51:37] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:51:37] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# | 10        | 0.7088    | 0.0       | 0.1       | 0.0       | 12.23     | 20.0      | 1.0       |
# [17:51:50] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:51:50] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:51:50] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:51:50] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:51:50] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# | 11        | 0.7119    | 0.0       | 0.1       | 0.0       | 5.0       | 13.22     | 0.5       |
# [17:52:03] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:52:03] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:52:03] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:52:03] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:52:03] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# | 12        | 0.7047    | 10.0      | 1.0       | 0.0       | 15.0      | 11.21     | 0.5       |
# [17:52:20] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:52:20] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:52:20] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:52:20] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:52:20] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# | 13        | 0.7189    | 10.0      | 1.0       | 0.0       | 5.0       | 6.95      | 1.0       |
# [17:52:43] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:52:43] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:52:43] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:52:43] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:52:43] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# | 14        | 0.7212    | 5.335     | 1.0       | 0.0       | 5.0       | 20.0      | 1.0       |
# [17:53:05] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:53:05] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:53:05] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:53:05] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:53:05] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# | 15        | 0.7181    | 10.0      | 1.0       | 0.0       | 5.0       | 1.0       | 1.0       |
# [17:53:23] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:53:23] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:53:23] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:53:23] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:53:23] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# | 16        | 0.7201    | 4.897     | 1.0       | 0.0       | 5.0       | 14.76     | 1.0       |
# [17:53:42] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:53:42] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:53:42] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:53:42] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:53:42] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# | 17        | 0.7125    | 4.007     | 0.1       | 0.0       | 7.975     | 17.43     | 0.5       |
# [17:53:57] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:53:57] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:53:57] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:53:57] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:53:57] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# | 18        | 0.7197    | 4.662     | 1.0       | 0.0       | 5.0       | 6.328     | 1.0       |
# [17:54:12] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:54:12] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:54:12] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:54:12] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:54:12] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# | 19        | 0.6601    | 10.0      | 1.0       | 7.692     | 5.0       | 1.0       | 1.0       |
# [17:54:16] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:54:16] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:54:16] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:54:16] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:54:16] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# | 20        | 0.6616    | 10.0      | 1.0       | 7.149     | 5.0       | 20.0      | 1.0       |
# [17:54:21] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:54:21] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:54:21] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:54:21] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:54:21] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# | 21        | 0.7133    | 0.0       | 1.0       | 0.0       | 5.0       | 1.0       | 0.5       |
# [17:54:39] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:54:39] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:54:40] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:54:40] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:54:40] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# | 22        | 0.6989    | 0.0       | 1.0       | 0.0       | 15.0      | 13.17     | 1.0       |
# [17:54:59] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:54:59] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:54:59] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:54:59] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:54:59] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# | 23        | 0.7195    | 4.837     | 1.0       | 0.0       | 7.929     | 10.52     | 1.0       |
# [17:55:14] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:55:14] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:55:14] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:55:14] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:55:14] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# | 24        | 0.7148    | 5.518     | 0.1       | 0.0       | 5.0       | 1.0       | 0.5       |
# [17:55:30] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:55:30] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:55:30] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:55:30] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:55:30] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# | 25        | 0.7146    | 6.936     | 0.1       | 0.0       | 5.0       | 10.6      | 0.5       |
# [17:55:48] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:55:48] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:55:48] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:55:48] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:55:48] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# | 26        | 0.7157    | 10.0      | 1.0       | 0.0       | 9.753     | 15.08     | 1.0       |
# [17:56:04] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:56:04] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:56:04] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:56:04] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:56:04] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# | 27        | 0.7185    | 8.039     | 1.0       | 0.0       | 7.74      | 4.553     | 1.0       |
# [17:56:20] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:56:20] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:56:20] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:56:20] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:56:20] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# | 28        | 0.7161    | 0.0       | 1.0       | 0.0       | 5.0       | 6.607     | 1.0       |
# [17:56:32] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:56:32] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:56:32] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:56:32] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:56:32] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# | 29        | 0.6613    | 0.0       | 1.0       | 10.0      | 15.0      | 20.0      | 1.0       |
# [17:56:45] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:56:45] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:56:45] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:56:45] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# [17:56:45] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "cosample_bytree", "silent", "verbose_eval" } are not used.
#
# | 30        | 0.7178    | 8.068     | 1.0       | 0.0       | 7.627     | 12.63     | 1.0       |
# =================================================================================================
# bayesianSearch for xgb spend 765.5525000095367 seconds.
